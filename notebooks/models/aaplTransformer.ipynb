# %%
import pandas as pd
import datetime as dt
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, regularizers, Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, GlobalAveragePooling1D, LayerNormalization, MultiHeadAttention, Add
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from textblob import TextBlob
from sklearn.feature_extraction.text import CountVectorizer
from transformers import pipeline
import string
from sklearn.preprocessing import MinMaxScaler
import keras_tuner as kt

# %%
X_train = pd.read_csv('../../data/input_data_splits/aapl_X_train.csv')
y_train = pd.read_csv('../../data/input_data_splits/aapl_y_train.csv')
X_dev = pd.read_csv('../../data/input_data_splits/aapl_X_dev.csv')
y_dev = pd.read_csv('../../data/input_data_splits/aapl_y_dev.csv')
X_test = pd.read_csv('../../data/input_data_splits/aapl_X_test.csv')
y_test = pd.read_csv('../../data/input_data_splits/aapl_y_test.csv')

X_train['Date'] = pd.to_datetime(X_train['Date'])
X_train.set_index('Date', inplace=True)

X_dev['Date'] = pd.to_datetime(X_dev['Date'])
X_dev.set_index('Date', inplace=True)

X_test['Date'] = pd.to_datetime(X_test['Date'])
X_test.set_index('Date', inplace=True)

y_train = y_train['Close']
y_dev = y_dev['Close']
y_test = y_test['Close']

# %%
# Parameters
lookback = 5
n_features = 25

# Scale features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_dev_scaled = scaler_X.fit_transform(X_dev)
X_test_scaled = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1,1))
y_dev_scaled = scaler_y.fit_transform(y_dev.values.reshape(-1,1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1,1))

def create_sequences(X, y, lookback):
    Xs, ys = [], []
    for i in range(len(X) - lookback + 1):
        Xs.append(X[i:i+lookback])
        ys.append(y[i+lookback-1])
    return np.array(Xs), np.array(ys)

X_train, y_train = create_sequences(X_train_scaled, y_train_scaled, lookback)
X_dev, y_dev = create_sequences(X_dev_scaled, y_dev_scaled, lookback)
X_test, y_test = create_sequences(X_test_scaled, y_test_scaled, lookback)

# %%
X_combined = np.concatenate((X_train, X_dev), axis=0)
y_combined = np.concatenate((y_train, y_dev), axis=0)

# %%
class PositionalEncoding(layers.Layer):
    def __init__(self, sequence_length, embed_dim):
        super(PositionalEncoding, self).__init__()
        self.sequence_length = sequence_length
        self.embed_dim = embed_dim

    def call(self, inputs):
        # Create a matrix for positional encodings
        positions = tf.range(self.sequence_length, dtype=tf.float32)[:, tf.newaxis]
        dimensions = tf.range(self.embed_dim, dtype=tf.float32)[tf.newaxis, :]

        # Compute sinusoidal encoding
        angle_rates = 1 / tf.pow(10000.0, (2 * (dimensions // 2)) / tf.cast(self.embed_dim, tf.float32))
        angle_rads = positions * angle_rates

        # Apply sine to even indices and cosine to odd indices
        pos_encoding = tf.concat([tf.sin(angle_rads[:, 0::2]), tf.cos(angle_rads[:, 1::2])], axis=-1)
        pos_encoding = tf.expand_dims(pos_encoding, axis=0)  # Add batch dimension

        return inputs + pos_encoding

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Add()([x, inputs])

    # Feed Forward Part
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation="relu")(y)
    y = Dropout(dropout)(y)
    y = Dense(inputs.shape[-1])(y)
    return Add()([y, x])

def build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout=0):
    sequence_length = input_shape[0]
    embed_dim = input_shape[1]

    # Input layer
    inputs = Input(shape=input_shape)

    # Positional Encoding
    x = PositionalEncoding(sequence_length, embed_dim)(inputs)

    # Create multiple layers of the Transformer block
    for _ in range(num_layers):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    # Final part of the model
    x = GlobalAveragePooling1D()(x)
    x = LayerNormalization(epsilon=1e-6)(x)
    outputs = Dense(1, activation="linear")(x)

    # Build and compile the model
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Model parameters
input_shape = X_combined.shape[1:]  # Shape of input data: (sequence_length, num_features)
head_size = 256
num_heads = 16
ff_dim = 1024
num_layers = 12
dropout = 0.20

# Build the model
model = build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 5, 25)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encodin… │ (None, 5, 25)     │          0 │ input_layer_1[0]… │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ positional_encod… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 5, 1024)   │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 5, 25)     │          0 │ dense_10[0][0],   │
# │                     │                   │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 5, 1024)   │          0 │ dense_11[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 5, 25)     │          0 │ dense_12[0][0],   │
# │                     │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 5, 1024)   │          0 │ dense_13[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 5, 25)     │          0 │ dense_14[0][0],   │
# │                     │                   │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 5, 1024)   │          0 │ dense_15[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 5, 25)     │          0 │ dense_16[0][0],   │
# │                     │                   │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 5, 1024)   │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 5, 25)     │          0 │ dense_18[0][0],   │
# │                     │                   │            │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 5, 1024)   │          0 │ dense_19[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 5, 25)     │          0 │ dense_20[0][0],   │
# │                     │                   │            │ add_18[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_19[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_20[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 5, 1024)   │          0 │ dense_21[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 5, 25)     │          0 │ dense_22[0][0],   │
# │                     │                   │            │ add_20[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_21[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_21[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_22[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 5, 1024)   │          0 │ dense_23[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 5, 25)     │          0 │ dense_24[0][0],   │
# │                     │                   │            │ add_22[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_23[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_23[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_24[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_25 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 5, 1024)   │          0 │ dense_25[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 5, 25)     │          0 │ dense_26[0][0],   │
# │                     │                   │            │ add_24[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_25[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_25[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_26[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 5, 1024)   │          0 │ dense_27[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_27[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 5, 25)     │          0 │ dense_28[0][0],   │
# │                     │                   │            │ add_26[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_27[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_27[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_28[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_29 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 5, 1024)   │          0 │ dense_29[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_29[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 5, 25)     │          0 │ dense_30[0][0],   │
# │                     │                   │            │ add_28[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_29[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 25)     │    421,913 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_30 (Add)        │ (None, 5, 25)     │          0 │ multi_head_atten… │
# │                     │                   │            │ add_29[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 25)     │         50 │ add_30[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 5, 1024)   │     26,624 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 5, 1024)   │          0 │ dense_31[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 5, 25)     │     25,625 │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_31 (Add)        │ (None, 5, 25)     │          0 │ dense_32[0][0],   │
# │                     │                   │            │ add_30[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 25)        │          0 │ add_31[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 25)        │         50 │ global_average_p… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 1)         │         26 │ layer_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,691,220 (21.71 MB)
#  Trainable params: 5,691,220 (21.71 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def custom_mae_loss(y_true, y_pred):
    # Both y_true and y_pred are 1D after slicing, so direct calculation works
    abs_error = tf.abs(tf.cast(y_true, tf.float64) - tf.cast(y_pred, tf.float64))
    return tf.reduce_mean(abs_error)


def dir_acc(y_true, y_pred):
    # Cast to float for compatibility
    y_true = tf.cast(y_true, tf.float64)
    y_pred = tf.cast(y_pred, tf.float64)
    
    # Calculate directional changes (diff between consecutive elements)
    y_true_diff = tf.sign(y_true[1:] - y_true[:-1])
    y_pred_diff = tf.sign(y_pred[1:] - y_pred[:-1])
    
    # Check if directions match
    correct_directions = tf.equal(y_true_diff, y_pred_diff)
    
    # Return mean accuracy over the batch
    return tf.reduce_mean(tf.cast(correct_directions, tf.float64))

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=custom_mae_loss,
              metrics=[dir_acc])

# %%
# Define a callback to save the best model
checkpoint_callback_train = ModelCheckpoint(
    "transformer_train_model.keras",  # Filepath to save the best model
    monitor="dir_acc",  #"loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

# Define a callback to save the best model
checkpoint_callback_val = ModelCheckpoint(
    "transformer_val_model.keras",  # Filepath to save the best model
    monitor="val_dir_acc", #"val_loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

def get_lr_callback(batch_size=16, mode='cos', epochs=500, plot=False):
    lr_start, lr_max, lr_min = 0.0001, 0.005, 0.00001  # Adjust learning rate boundaries
    lr_ramp_ep = int(0.30 * epochs)  # 30% of epochs for warm-up
    lr_sus_ep = max(0, int(0.10 * epochs) - lr_ramp_ep)  # Optional sustain phase, adjust as needed

    def lrfn(epoch):
        if epoch < lr_ramp_ep:  # Warm-up phase
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        elif epoch < lr_ramp_ep + lr_sus_ep:  # Sustain phase at max learning rate
            lr = lr_max
        elif mode == 'cos':
            decay_total_epochs, decay_epoch_index = epochs - lr_ramp_ep - lr_sus_ep, epoch - lr_ramp_ep - lr_sus_ep
            phase = math.pi * decay_epoch_index / decay_total_epochs
            lr = (lr_max - lr_min) * 0.5 * (1 + math.cos(phase)) + lr_min
        else:
            lr = lr_min  # Default to minimum learning rate if mode is not recognized

        return lr

    if plot:  # Plot learning rate curve if plot is True
        plt.figure(figsize=(10, 5))
        plt.plot(np.arange(epochs), [lrfn(epoch) for epoch in np.arange(epochs)], marker='o')
        plt.xlabel('Epoch')
        plt.ylabel('Learning Rate')
        plt.title('Learning Rate Scheduler')
        plt.show()

    return tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

# %%
BATCH_SIZE = 64
EPOCHS = 100
model.fit(X_train, y_train,
          validation_data=(X_dev, y_dev),
          epochs=EPOCHS,
          batch_size=BATCH_SIZE,
          shuffle=True,
          callbacks=[checkpoint_callback_train, checkpoint_callback_val, get_lr_callback(batch_size=BATCH_SIZE, epochs=EPOCHS, plot=True)])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dir_acc: 0.4734 - loss: 0.8899
# Epoch 1: dir_acc improved from -inf to 0.47141, saving model to transformer_train_model.keras
#
# Epoch 1: val_dir_acc improved from -inf to 0.45845, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - dir_acc: 0.4732 - loss: 0.8705 - val_dir_acc: 0.4585 - val_loss: 0.2712 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.00026333333333333336.
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - dir_acc: 0.6635 - loss: 0.2472
# Epoch 2: dir_acc improved from 0.47141 to 0.69940, saving model to transformer_train_model.keras
#
# Epoch 2: val_dir_acc did not improve from 0.45845
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 374ms/step - dir_acc: 0.6665 - loss: 0.2458 - val_dir_acc: 0.4374 - val_loss: 0.1732 - learning_rate: 2.6333e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00042666666666666667.
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - dir_acc: 0.7874 - loss: 0.1744
# Epoch 3: dir_acc improved from 0.69940 to 0.78328, saving model to transformer_train_model.keras
#
# Epoch 3: val_dir_acc did not improve from 0.45845
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 356ms/step - dir_acc: 0.7871 - loss: 0.1741 - val_dir_acc: 0.4351 - val_loss: 0.1861 - learning_rate: 4.2667e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.00059.
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - dir_acc: 0.7760 - loss: 0.1365
# Epoch 4: dir_acc did not improve from 0.78328
#
# Epoch 4: val_dir_acc did not improve from 0.45845
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - dir_acc: 0.7753 - loss: 0.1354 - val_dir_acc: 0.4238 - val_loss: 0.1423 - learning_rate: 5.9000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0007533333333333334.
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - dir_acc: 0.8166 - loss: 0.1086
# Epoch 5: dir_acc improved from 0.78328 to 0.84668, saving model to transformer_train_model.keras
#
# Epoch 5: val_dir_acc improved from 0.45845 to 0.49568, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 456ms/step - dir_acc: 0.8191 - loss: 0.1091 - val_dir_acc: 0.4957 - val_loss: 0.1018 - learning_rate: 7.5333e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0009166666666666668.
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - dir_acc: 0.8928 - loss: 0.0791
# Epoch 6: dir_acc improved from 0.84668 to 0.88330, saving model to transformer_train_model.keras
#
# Epoch 6: val_dir_acc improved from 0.49568 to 0.54610, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 413ms/step - dir_acc: 0.8920 - loss: 0.0786 - val_dir_acc: 0.5461 - val_loss: 0.1591 - learning_rate: 9.1667e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00108.
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - dir_acc: 0.8988 - loss: 0.0727
# Epoch 7: dir_acc improved from 0.88330 to 0.88429, saving model to transformer_train_model.keras
#
# Epoch 7: val_dir_acc improved from 0.54610 to 0.55742, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 368ms/step - dir_acc: 0.8976 - loss: 0.0727 - val_dir_acc: 0.5574 - val_loss: 0.1734 - learning_rate: 0.0011
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0012433333333333335.
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - dir_acc: 0.8850 - loss: 0.1059
# Epoch 8: dir_acc improved from 0.88429 to 0.88817, saving model to transformer_train_model.keras
#
# Epoch 8: val_dir_acc did not improve from 0.55742
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - dir_acc: 0.8853 - loss: 0.1064 - val_dir_acc: 0.5387 - val_loss: 0.1105 - learning_rate: 0.0012
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0014066666666666667.
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - dir_acc: 0.8853 - loss: 0.0892
# Epoch 9: dir_acc did not improve from 0.88817
#
# Epoch 9: val_dir_acc improved from 0.55742 to 0.56874, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - dir_acc: 0.8855 - loss: 0.0892 - val_dir_acc: 0.5687 - val_loss: 0.1339 - learning_rate: 0.0014
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.00157.
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - dir_acc: 0.8863 - loss: 0.0925
# Epoch 10: dir_acc improved from 0.88817 to 0.89340, saving model to transformer_train_model.keras
#
# Epoch 10: val_dir_acc did not improve from 0.56874
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - dir_acc: 0.8869 - loss: 0.0921 - val_dir_acc: 0.5687 - val_loss: 0.1528 - learning_rate: 0.0016
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0017333333333333335.
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - dir_acc: 0.9089 - loss: 0.0831
# Epoch 11: dir_acc improved from 0.89340 to 0.91495, saving model to transformer_train_model.keras
#
# Epoch 11: val_dir_acc improved from 0.56874 to 0.58007, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 348ms/step - dir_acc: 0.9094 - loss: 0.0839 - val_dir_acc: 0.5801 - val_loss: 0.1011 - learning_rate: 0.0017
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0018966666666666667.
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - dir_acc: 0.9332 - loss: 0.0740
# Epoch 12: dir_acc improved from 0.91495 to 0.93128, saving model to transformer_train_model.keras
#
# Epoch 12: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - dir_acc: 0.9330 - loss: 0.0741 - val_dir_acc: 0.5682 - val_loss: 0.0883 - learning_rate: 0.0019
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0020599999999999998.
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - dir_acc: 0.8889 - loss: 0.0807
# Epoch 13: dir_acc did not improve from 0.93128
#
# Epoch 13: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 316ms/step - dir_acc: 0.8880 - loss: 0.0805 - val_dir_acc: 0.5801 - val_loss: 0.0826 - learning_rate: 0.0021
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0022233333333333332.
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - dir_acc: 0.9184 - loss: 0.1103
# Epoch 14: dir_acc did not improve from 0.93128
#
# Epoch 14: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 316ms/step - dir_acc: 0.9183 - loss: 0.1112 - val_dir_acc: 0.5721 - val_loss: 0.1424 - learning_rate: 0.0022
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0023866666666666667.
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - dir_acc: 0.9174 - loss: 0.1398
# Epoch 15: dir_acc did not improve from 0.93128
#
# Epoch 15: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - dir_acc: 0.9171 - loss: 0.1386 - val_dir_acc: 0.5455 - val_loss: 0.1066 - learning_rate: 0.0024
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0025499999999999997.
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - dir_acc: 0.8870 - loss: 0.1043
# Epoch 16: dir_acc did not improve from 0.93128
#
# Epoch 16: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - dir_acc: 0.8880 - loss: 0.1041 - val_dir_acc: 0.5489 - val_loss: 0.0940 - learning_rate: 0.0026
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0027133333333333332.
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - dir_acc: 0.9178 - loss: 0.0873
# Epoch 17: dir_acc did not improve from 0.93128
#
# Epoch 17: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - dir_acc: 0.9169 - loss: 0.0862 - val_dir_acc: 0.5568 - val_loss: 0.1033 - learning_rate: 0.0027
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0028766666666666667.
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - dir_acc: 0.9119 - loss: 0.0562
# Epoch 18: dir_acc did not improve from 0.93128
#
# Epoch 18: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 318ms/step - dir_acc: 0.9116 - loss: 0.0569 - val_dir_acc: 0.5415 - val_loss: 0.1540 - learning_rate: 0.0029
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0030399999999999997.
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - dir_acc: 0.8880 - loss: 0.1074
# Epoch 19: dir_acc did not improve from 0.93128
#
# Epoch 19: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - dir_acc: 0.8901 - loss: 0.1067 - val_dir_acc: 0.5342 - val_loss: 0.0987 - learning_rate: 0.0030
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.003203333333333333.
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - dir_acc: 0.9204 - loss: 0.0924
# Epoch 20: dir_acc did not improve from 0.93128
#
# Epoch 20: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 314ms/step - dir_acc: 0.9200 - loss: 0.0924 - val_dir_acc: 0.5489 - val_loss: 0.0991 - learning_rate: 0.0032
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0033666666666666667.
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - dir_acc: 0.8856 - loss: 0.0788
# Epoch 21: dir_acc did not improve from 0.93128
#
# Epoch 21: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 323ms/step - dir_acc: 0.8856 - loss: 0.0785 - val_dir_acc: 0.5574 - val_loss: 0.1300 - learning_rate: 0.0034
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0035299999999999997.
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - dir_acc: 0.8980 - loss: 0.0613
# Epoch 22: dir_acc did not improve from 0.93128
#
# Epoch 22: val_dir_acc did not improve from 0.58007
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 321ms/step - dir_acc: 0.8981 - loss: 0.0609 - val_dir_acc: 0.5654 - val_loss: 0.1030 - learning_rate: 0.0035
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.003693333333333333.
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - dir_acc: 0.9069 - loss: 0.0493
# Epoch 23: dir_acc did not improve from 0.93128
#
# Epoch 23: val_dir_acc improved from 0.58007 to 0.59255, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 372ms/step - dir_acc: 0.9081 - loss: 0.0495 - val_dir_acc: 0.5926 - val_loss: 0.0932 - learning_rate: 0.0037
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0038566666666666667.
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dir_acc: 0.9124 - loss: 0.0427
# Epoch 24: dir_acc did not improve from 0.93128
#
# Epoch 24: val_dir_acc improved from 0.59255 to 0.60784, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - dir_acc: 0.9126 - loss: 0.0430 - val_dir_acc: 0.6078 - val_loss: 0.0730 - learning_rate: 0.0039
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.00402.
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - dir_acc: 0.9543 - loss: 0.0770
# Epoch 25: dir_acc improved from 0.93128 to 0.93948, saving model to transformer_train_model.keras
#
# Epoch 25: val_dir_acc did not improve from 0.60784
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 347ms/step - dir_acc: 0.9531 - loss: 0.0779 - val_dir_acc: 0.5959 - val_loss: 0.1248 - learning_rate: 0.0040
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.004183333333333334.
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - dir_acc: 0.9093 - loss: 0.0900
# Epoch 26: dir_acc did not improve from 0.93948
#
# Epoch 26: val_dir_acc did not improve from 0.60784
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 317ms/step - dir_acc: 0.9098 - loss: 0.0909 - val_dir_acc: 0.6045 - val_loss: 0.0866 - learning_rate: 0.0042
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.004346666666666667.
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dir_acc: 0.9214 - loss: 0.0867
# Epoch 27: dir_acc did not improve from 0.93948
#
# Epoch 27: val_dir_acc did not improve from 0.60784
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 328ms/step - dir_acc: 0.9207 - loss: 0.0856 - val_dir_acc: 0.5999 - val_loss: 0.0911 - learning_rate: 0.0043
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00451.
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - dir_acc: 0.9095 - loss: 0.0545
# Epoch 28: dir_acc did not improve from 0.93948
#
# Epoch 28: val_dir_acc improved from 0.60784 to 0.61916, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - dir_acc: 0.9106 - loss: 0.0548 - val_dir_acc: 0.6192 - val_loss: 0.1584 - learning_rate: 0.0045
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.004673333333333334.
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - dir_acc: 0.9123 - loss: 0.0889
# Epoch 29: dir_acc did not improve from 0.93948
#
# Epoch 29: val_dir_acc did not improve from 0.61916
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - dir_acc: 0.9125 - loss: 0.0876 - val_dir_acc: 0.5767 - val_loss: 0.0820 - learning_rate: 0.0047
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.004836666666666667.
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - dir_acc: 0.9259 - loss: 0.0551
# Epoch 30: dir_acc did not improve from 0.93948
#
# Epoch 30: val_dir_acc did not improve from 0.61916
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 326ms/step - dir_acc: 0.9252 - loss: 0.0548 - val_dir_acc: 0.5965 - val_loss: 0.0932 - learning_rate: 0.0048
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.005.
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - dir_acc: 0.9174 - loss: 0.0471
# Epoch 31: dir_acc did not improve from 0.93948
#
# Epoch 31: val_dir_acc did not improve from 0.61916
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 358ms/step - dir_acc: 0.9173 - loss: 0.0478 - val_dir_acc: 0.6152 - val_loss: 0.1361 - learning_rate: 0.0050
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00499748770102058.
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dir_acc: 0.9401 - loss: 0.0990
# Epoch 32: dir_acc improved from 0.93948 to 0.94372, saving model to transformer_train_model.keras
#
# Epoch 32: val_dir_acc did not improve from 0.61916
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - dir_acc: 0.9404 - loss: 0.0992 - val_dir_acc: 0.5926 - val_loss: 0.0921 - learning_rate: 0.0050
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0049899558635181215.
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - dir_acc: 0.9367 - loss: 0.0769
# Epoch 33: dir_acc did not improve from 0.94372
#
# Epoch 33: val_dir_acc did not improve from 0.61916
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 326ms/step - dir_acc: 0.9370 - loss: 0.0770 - val_dir_acc: 0.5806 - val_loss: 0.0949 - learning_rate: 0.0050
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.004977419655610997.
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dir_acc: 0.8949 - loss: 0.0681
# Epoch 34: dir_acc did not improve from 0.94372
#
# Epoch 34: val_dir_acc did not improve from 0.61916
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 325ms/step - dir_acc: 0.8958 - loss: 0.0676 - val_dir_acc: 0.5926 - val_loss: 0.1158 - learning_rate: 0.0050
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.004959904323553581.
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - dir_acc: 0.9468 - loss: 0.0571
# Epoch 35: dir_acc did not improve from 0.94372
#
# Epoch 35: val_dir_acc did not improve from 0.61916
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 320ms/step - dir_acc: 0.9464 - loss: 0.0573 - val_dir_acc: 0.6005 - val_loss: 0.0722 - learning_rate: 0.0050
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0049374451408936496.
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - dir_acc: 0.9286 - loss: 0.0476
# Epoch 36: dir_acc did not improve from 0.94372
#
# Epoch 36: val_dir_acc did not improve from 0.61916
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 319ms/step - dir_acc: 0.9289 - loss: 0.0474 - val_dir_acc: 0.5959 - val_loss: 0.0714 - learning_rate: 0.0049
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.004910087337436154.
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - dir_acc: 0.9040 - loss: 0.0497
# Epoch 37: dir_acc did not improve from 0.94372
#
# Epoch 37: val_dir_acc improved from 0.61916 to 0.61975, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 336ms/step - dir_acc: 0.9050 - loss: 0.0498 - val_dir_acc: 0.6197 - val_loss: 0.0794 - learning_rate: 0.0049
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.004877886008156408.
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - dir_acc: 0.9206 - loss: 0.0613
# Epoch 38: dir_acc did not improve from 0.94372
#
# Epoch 38: val_dir_acc did not improve from 0.61975
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 321ms/step - dir_acc: 0.9208 - loss: 0.0609 - val_dir_acc: 0.6192 - val_loss: 0.1027 - learning_rate: 0.0049
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.004840906002246144.
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - dir_acc: 0.9278 - loss: 0.0462
# Epoch 39: dir_acc did not improve from 0.94372
#
# Epoch 39: val_dir_acc improved from 0.61975 to 0.62768, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - dir_acc: 0.9280 - loss: 0.0459 - val_dir_acc: 0.6277 - val_loss: 0.0781 - learning_rate: 0.0048
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00479922179251587.
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - dir_acc: 0.9473 - loss: 0.0438
# Epoch 40: dir_acc improved from 0.94372 to 0.94814, saving model to transformer_train_model.keras
#
# Epoch 40: val_dir_acc did not improve from 0.62768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 366ms/step - dir_acc: 0.9474 - loss: 0.0441 - val_dir_acc: 0.6255 - val_loss: 0.0771 - learning_rate: 0.0048
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0047529173254165355.
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - dir_acc: 0.9387 - loss: 0.0596
# Epoch 41: dir_acc did not improve from 0.94814
#
# Epoch 41: val_dir_acc did not improve from 0.62768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 318ms/step - dir_acc: 0.9380 - loss: 0.0597 - val_dir_acc: 0.6078 - val_loss: 0.1199 - learning_rate: 0.0048
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.004702085851982562.
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - dir_acc: 0.9349 - loss: 0.0575
# Epoch 42: dir_acc did not improve from 0.94814
#
# Epoch 42: val_dir_acc did not improve from 0.62768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 328ms/step - dir_acc: 0.9351 - loss: 0.0570 - val_dir_acc: 0.6084 - val_loss: 0.0770 - learning_rate: 0.0047
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.004646829740036656.
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - dir_acc: 0.9310 - loss: 0.0377
# Epoch 43: dir_acc did not improve from 0.94814
#
# Epoch 43: val_dir_acc improved from 0.62768 to 0.65488, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 339ms/step - dir_acc: 0.9311 - loss: 0.0376 - val_dir_acc: 0.6549 - val_loss: 0.0690 - learning_rate: 0.0046
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.00458726026803465.
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - dir_acc: 0.9151 - loss: 0.0330
# Epoch 44: dir_acc did not improve from 0.94814
#
# Epoch 44: val_dir_acc did not improve from 0.65488
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 317ms/step - dir_acc: 0.9153 - loss: 0.0330 - val_dir_acc: 0.6390 - val_loss: 0.0653 - learning_rate: 0.0046
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.004523497400965494.
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - dir_acc: 0.9166 - loss: 0.0353
# Epoch 45: dir_acc did not improve from 0.94814
#
# Epoch 45: val_dir_acc did not improve from 0.65488
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 340ms/step - dir_acc: 0.9176 - loss: 0.0355 - val_dir_acc: 0.6464 - val_loss: 0.0818 - learning_rate: 0.0045
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.004455669548757734.
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - dir_acc: 0.9260 - loss: 0.0498
# Epoch 46: dir_acc did not improve from 0.94814
#
# Epoch 46: val_dir_acc did not improve from 0.65488
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - dir_acc: 0.9263 - loss: 0.0499 - val_dir_acc: 0.6345 - val_loss: 0.1149 - learning_rate: 0.0045
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00438391330767901.
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - dir_acc: 0.9239 - loss: 0.0570
# Epoch 47: dir_acc did not improve from 0.94814
#
# Epoch 47: val_dir_acc did not improve from 0.65488
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 330ms/step - dir_acc: 0.9248 - loss: 0.0569 - val_dir_acc: 0.6299 - val_loss: 0.0835 - learning_rate: 0.0044
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.004308373185249342.
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - dir_acc: 0.9519 - loss: 0.0454
# Epoch 48: dir_acc did not improve from 0.94814
#
# Epoch 48: val_dir_acc did not improve from 0.65488
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 346ms/step - dir_acc: 0.9510 - loss: 0.0454 - val_dir_acc: 0.6225 - val_loss: 0.0872 - learning_rate: 0.0043
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.004229201309222228.
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - dir_acc: 0.9157 - loss: 0.0390
# Epoch 49: dir_acc did not improve from 0.94814
#
# Epoch 49: val_dir_acc improved from 0.65488 to 0.65768, saving model to transformer_val_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - dir_acc: 0.9159 - loss: 0.0388 - val_dir_acc: 0.6577 - val_loss: 0.0828 - learning_rate: 0.0042
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0041465571212195825.
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dir_acc: 0.9215 - loss: 0.0350
# Epoch 50: dir_acc did not improve from 0.94814
#
# Epoch 50: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 336ms/step - dir_acc: 0.9216 - loss: 0.0348 - val_dir_acc: 0.6497 - val_loss: 0.0684 - learning_rate: 0.0041
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0040606070556375405.
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - dir_acc: 0.9247 - loss: 0.0309
# Epoch 51: dir_acc did not improve from 0.94814
#
# Epoch 51: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 345ms/step - dir_acc: 0.9250 - loss: 0.0310 - val_dir_acc: 0.6464 - val_loss: 0.0804 - learning_rate: 0.0041
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.00397152420446972.
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - dir_acc: 0.9565 - loss: 0.0321
# Epoch 52: dir_acc did not improve from 0.94814
#
# Epoch 52: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 360ms/step - dir_acc: 0.9550 - loss: 0.0322 - val_dir_acc: 0.6378 - val_loss: 0.0724 - learning_rate: 0.0040
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.0038794879687229964.
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - dir_acc: 0.9116 - loss: 0.0311
# Epoch 53: dir_acc did not improve from 0.94814
#
# Epoch 53: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - dir_acc: 0.9126 - loss: 0.0312 - val_dir_acc: 0.6339 - val_loss: 0.0702 - learning_rate: 0.0039
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0037846836971277367.
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - dir_acc: 0.9640 - loss: 0.0363
# Epoch 54: dir_acc improved from 0.94814 to 0.95725, saving model to transformer_train_model.keras
#
# Epoch 54: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 358ms/step - dir_acc: 0.9634 - loss: 0.0359 - val_dir_acc: 0.6299 - val_loss: 0.0740 - learning_rate: 0.0038
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.003687302312870132.
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - dir_acc: 0.9601 - loss: 0.0306
# Epoch 55: dir_acc did not improve from 0.95725
#
# Epoch 55: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 353ms/step - dir_acc: 0.9588 - loss: 0.0309 - val_dir_acc: 0.6220 - val_loss: 0.0789 - learning_rate: 0.0037
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0035875399290983077.
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - dir_acc: 0.9490 - loss: 0.0319
# Epoch 56: dir_acc did not improve from 0.95725
#
# Epoch 56: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 357ms/step - dir_acc: 0.9487 - loss: 0.0319 - val_dir_acc: 0.6192 - val_loss: 0.0907 - learning_rate: 0.0036
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00348559745397654.
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - dir_acc: 0.9403 - loss: 0.0389
# Epoch 57: dir_acc did not improve from 0.95725
#
# Epoch 57: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 363ms/step - dir_acc: 0.9399 - loss: 0.0388 - val_dir_acc: 0.6073 - val_loss: 0.0709 - learning_rate: 0.0035
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0033816801860829505.
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - dir_acc: 0.9574 - loss: 0.0461
# Epoch 58: dir_acc improved from 0.95725 to 0.96780, saving model to transformer_train_model.keras
#
# Epoch 58: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 373ms/step - dir_acc: 0.9583 - loss: 0.0455 - val_dir_acc: 0.6106 - val_loss: 0.0936 - learning_rate: 0.0034
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0032759974009654944.
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - dir_acc: 0.9582 - loss: 0.0349
# Epoch 59: dir_acc did not improve from 0.96780
#
# Epoch 59: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 352ms/step - dir_acc: 0.9585 - loss: 0.0348 - val_dir_acc: 0.6299 - val_loss: 0.0700 - learning_rate: 0.0033
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0031687619296888545.
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dir_acc: 0.9570 - loss: 0.0329
# Epoch 60: dir_acc did not improve from 0.96780
#
# Epoch 60: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 331ms/step - dir_acc: 0.9572 - loss: 0.0332 - val_dir_acc: 0.6378 - val_loss: 0.0787 - learning_rate: 0.0032
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.003060189730221005.
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - dir_acc: 0.9313 - loss: 0.0381
# Epoch 61: dir_acc did not improve from 0.96780
#
# Epoch 61: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 345ms/step - dir_acc: 0.9320 - loss: 0.0382 - val_dir_acc: 0.6231 - val_loss: 0.0729 - learning_rate: 0.0031
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.002950499452522599.
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - dir_acc: 0.9342 - loss: 0.0361
# Epoch 62: dir_acc did not improve from 0.96780
#
# Epoch 62: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - dir_acc: 0.9348 - loss: 0.0359 - val_dir_acc: 0.6311 - val_loss: 0.0709 - learning_rate: 0.0030
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0028399119982150506.
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - dir_acc: 0.9493 - loss: 0.0266
# Epoch 63: dir_acc did not improve from 0.96780
#
# Epoch 63: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 331ms/step - dir_acc: 0.9492 - loss: 0.0266 - val_dir_acc: 0.6464 - val_loss: 0.0792 - learning_rate: 0.0028
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.002728650075714067.
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dir_acc: 0.9508 - loss: 0.0258
# Epoch 64: dir_acc did not improve from 0.96780
#
# Epoch 64: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - dir_acc: 0.9506 - loss: 0.0260 - val_dir_acc: 0.6164 - val_loss: 0.0752 - learning_rate: 0.0027
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0026169377517245352.
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - dir_acc: 0.9545 - loss: 0.0271
# Epoch 65: dir_acc did not improve from 0.96780
#
# Epoch 65: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - dir_acc: 0.9538 - loss: 0.0273 - val_dir_acc: 0.6192 - val_loss: 0.0698 - learning_rate: 0.0026
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.0025050000000000003.
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - dir_acc: 0.9538 - loss: 0.0295
# Epoch 66: dir_acc did not improve from 0.96780
#
# Epoch 66: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - dir_acc: 0.9526 - loss: 0.0295 - val_dir_acc: 0.6350 - val_loss: 0.0875 - learning_rate: 0.0025
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0023930622482754658.
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - dir_acc: 0.9312 - loss: 0.0304
# Epoch 67: dir_acc did not improve from 0.96780
#
# Epoch 67: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 336ms/step - dir_acc: 0.9316 - loss: 0.0305 - val_dir_acc: 0.6050 - val_loss: 0.0830 - learning_rate: 0.0024
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.002281349924285934.
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - dir_acc: 0.9492 - loss: 0.0312
# Epoch 68: dir_acc did not improve from 0.96780
#
# Epoch 68: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - dir_acc: 0.9480 - loss: 0.0312 - val_dir_acc: 0.6384 - val_loss: 0.0792 - learning_rate: 0.0023
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.00217008800178495.
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - dir_acc: 0.9353 - loss: 0.0302
# Epoch 69: dir_acc did not improve from 0.96780
#
# Epoch 69: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - dir_acc: 0.9355 - loss: 0.0303 - val_dir_acc: 0.6271 - val_loss: 0.0697 - learning_rate: 0.0022
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.002059500547477402.
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dir_acc: 0.9552 - loss: 0.0257
# Epoch 70: dir_acc did not improve from 0.96780
#
# Epoch 70: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 361ms/step - dir_acc: 0.9557 - loss: 0.0257 - val_dir_acc: 0.6424 - val_loss: 0.0705 - learning_rate: 0.0021
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.001949810269778996.
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - dir_acc: 0.9572 - loss: 0.0281
# Epoch 71: dir_acc did not improve from 0.96780
#
# Epoch 71: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 361ms/step - dir_acc: 0.9578 - loss: 0.0283 - val_dir_acc: 0.6384 - val_loss: 0.0708 - learning_rate: 0.0019
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0018412380703111465.
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - dir_acc: 0.9599 - loss: 0.0344
# Epoch 72: dir_acc did not improve from 0.96780
#
# Epoch 72: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 340ms/step - dir_acc: 0.9597 - loss: 0.0343 - val_dir_acc: 0.6311 - val_loss: 0.0686 - learning_rate: 0.0018
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0017340025990345066.
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - dir_acc: 0.9608 - loss: 0.0337
# Epoch 73: dir_acc did not improve from 0.96780
#
# Epoch 73: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 345ms/step - dir_acc: 0.9598 - loss: 0.0336 - val_dir_acc: 0.6277 - val_loss: 0.0725 - learning_rate: 0.0017
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0016283198139170505.
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - dir_acc: 0.9503 - loss: 0.0279
# Epoch 74: dir_acc did not improve from 0.96780
#
# Epoch 74: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 347ms/step - dir_acc: 0.9488 - loss: 0.0278 - val_dir_acc: 0.6118 - val_loss: 0.0747 - learning_rate: 0.0016
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0015244025460234615.
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - dir_acc: 0.9284 - loss: 0.0247
# Epoch 75: dir_acc did not improve from 0.96780
#
# Epoch 75: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 336ms/step - dir_acc: 0.9294 - loss: 0.0247 - val_dir_acc: 0.6158 - val_loss: 0.0780 - learning_rate: 0.0015
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.001422460070901693.
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - dir_acc: 0.9327 - loss: 0.0242
# Epoch 76: dir_acc did not improve from 0.96780
#
# Epoch 76: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - dir_acc: 0.9336 - loss: 0.0242 - val_dir_acc: 0.6231 - val_loss: 0.0748 - learning_rate: 0.0014
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0013226976871298685.
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - dir_acc: 0.9376 - loss: 0.0242
# Epoch 77: dir_acc did not improve from 0.96780
#
# Epoch 77: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - dir_acc: 0.9381 - loss: 0.0242 - val_dir_acc: 0.6112 - val_loss: 0.0794 - learning_rate: 0.0013
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.0012253163028722643.
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - dir_acc: 0.9453 - loss: 0.0247
# Epoch 78: dir_acc did not improve from 0.96780
#
# Epoch 78: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - dir_acc: 0.9455 - loss: 0.0247 - val_dir_acc: 0.6039 - val_loss: 0.0860 - learning_rate: 0.0012
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0011305120312770046.
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - dir_acc: 0.9494 - loss: 0.0279
# Epoch 79: dir_acc did not improve from 0.96780
#
# Epoch 79: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 323ms/step - dir_acc: 0.9496 - loss: 0.0277 - val_dir_acc: 0.6158 - val_loss: 0.0755 - learning_rate: 0.0011
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.00103847579553028.
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - dir_acc: 0.9704 - loss: 0.0225
# Epoch 80: dir_acc did not improve from 0.96780
#
# Epoch 80: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 331ms/step - dir_acc: 0.9695 - loss: 0.0226 - val_dir_acc: 0.6078 - val_loss: 0.0772 - learning_rate: 0.0010
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.00094939294436246.
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dir_acc: 0.9388 - loss: 0.0233
# Epoch 81: dir_acc did not improve from 0.96780
#
# Epoch 81: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 329ms/step - dir_acc: 0.9398 - loss: 0.0232 - val_dir_acc: 0.6118 - val_loss: 0.0789 - learning_rate: 9.4939e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.0008634428787804172.
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - dir_acc: 0.9383 - loss: 0.0235
# Epoch 82: dir_acc did not improve from 0.96780
#
# Epoch 82: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 349ms/step - dir_acc: 0.9381 - loss: 0.0236 - val_dir_acc: 0.6311 - val_loss: 0.0764 - learning_rate: 8.6344e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.0007807986907777728.
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - dir_acc: 0.9514 - loss: 0.0223
# Epoch 83: dir_acc did not improve from 0.96780
#
# Epoch 83: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 336ms/step - dir_acc: 0.9513 - loss: 0.0223 - val_dir_acc: 0.6192 - val_loss: 0.0763 - learning_rate: 7.8080e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0007016268147506584.
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dir_acc: 0.9627 - loss: 0.0225
# Epoch 84: dir_acc did not improve from 0.96780
#
# Epoch 84: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - dir_acc: 0.9620 - loss: 0.0224 - val_dir_acc: 0.6231 - val_loss: 0.0799 - learning_rate: 7.0163e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.000626086692320991.
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - dir_acc: 0.9584 - loss: 0.0232
# Epoch 85: dir_acc did not improve from 0.96780
#
# Epoch 85: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - dir_acc: 0.9579 - loss: 0.0232 - val_dir_acc: 0.6192 - val_loss: 0.0749 - learning_rate: 6.2609e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.000554330451242266.
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dir_acc: 0.9513 - loss: 0.0222
# Epoch 86: dir_acc did not improve from 0.96780
#
# Epoch 86: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 325ms/step - dir_acc: 0.9511 - loss: 0.0223 - val_dir_acc: 0.6192 - val_loss: 0.0759 - learning_rate: 5.5433e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.00048650259903450645.
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - dir_acc: 0.9240 - loss: 0.0223
# Epoch 87: dir_acc did not improve from 0.96780
#
# Epoch 87: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 353ms/step - dir_acc: 0.9247 - loss: 0.0223 - val_dir_acc: 0.6192 - val_loss: 0.0764 - learning_rate: 4.8650e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.00042273973196535.
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - dir_acc: 0.9507 - loss: 0.0221
# Epoch 88: dir_acc did not improve from 0.96780
#
# Epoch 88: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 358ms/step - dir_acc: 0.9507 - loss: 0.0221 - val_dir_acc: 0.6231 - val_loss: 0.0785 - learning_rate: 4.2274e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.00036317025996334415.
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - dir_acc: 0.9585 - loss: 0.0219
# Epoch 89: dir_acc did not improve from 0.96780
#
# Epoch 89: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 349ms/step - dir_acc: 0.9573 - loss: 0.0219 - val_dir_acc: 0.6192 - val_loss: 0.0794 - learning_rate: 3.6317e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.00030791414801743875.
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - dir_acc: 0.9407 - loss: 0.0207
# Epoch 90: dir_acc did not improve from 0.96780
#
# Epoch 90: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 332ms/step - dir_acc: 0.9410 - loss: 0.0208 - val_dir_acc: 0.6192 - val_loss: 0.0761 - learning_rate: 3.0791e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.00025708267458346456.
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - dir_acc: 0.9476 - loss: 0.0225
# Epoch 91: dir_acc did not improve from 0.96780
#
# Epoch 91: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 315ms/step - dir_acc: 0.9474 - loss: 0.0224 - val_dir_acc: 0.6192 - val_loss: 0.0778 - learning_rate: 2.5708e-04
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.00021077820748413085.
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dir_acc: 0.9537 - loss: 0.0214
# Epoch 92: dir_acc did not improve from 0.96780
#
# Epoch 92: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 330ms/step - dir_acc: 0.9535 - loss: 0.0214 - val_dir_acc: 0.6192 - val_loss: 0.0779 - learning_rate: 2.1078e-04
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.00016909399775385568.
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - dir_acc: 0.9737 - loss: 0.0212
# Epoch 93: dir_acc did not improve from 0.96780
#
# Epoch 93: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 332ms/step - dir_acc: 0.9729 - loss: 0.0213 - val_dir_acc: 0.6192 - val_loss: 0.0765 - learning_rate: 1.6909e-04
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.00013211399184359196.
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - dir_acc: 0.9537 - loss: 0.0216
# Epoch 94: dir_acc did not improve from 0.96780
#
# Epoch 94: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - dir_acc: 0.9532 - loss: 0.0216 - val_dir_acc: 0.6192 - val_loss: 0.0795 - learning_rate: 1.3211e-04
#
# Epoch 95: LearningRateScheduler setting learning rate to 9.991266256384617e-05.
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - dir_acc: 0.9727 - loss: 0.0215
# Epoch 95: dir_acc did not improve from 0.96780
#
# Epoch 95: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 332ms/step - dir_acc: 0.9720 - loss: 0.0215 - val_dir_acc: 0.6192 - val_loss: 0.0776 - learning_rate: 9.9913e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 7.255485910635008e-05.
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - dir_acc: 0.9564 - loss: 0.0211
# Epoch 96: dir_acc did not improve from 0.96780
#
# Epoch 96: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 330ms/step - dir_acc: 0.9561 - loss: 0.0211 - val_dir_acc: 0.6192 - val_loss: 0.0786 - learning_rate: 7.2555e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 5.009567644641898e-05.
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - dir_acc: 0.9564 - loss: 0.0216
# Epoch 97: dir_acc did not improve from 0.96780
#
# Epoch 97: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - dir_acc: 0.9561 - loss: 0.0215 - val_dir_acc: 0.6192 - val_loss: 0.0778 - learning_rate: 5.0096e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 3.258034438900293e-05.
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - dir_acc: 0.9414 - loss: 0.0215
# Epoch 98: dir_acc did not improve from 0.96780
#
# Epoch 98: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - dir_acc: 0.9423 - loss: 0.0215 - val_dir_acc: 0.6192 - val_loss: 0.0778 - learning_rate: 3.2580e-05
#
# Epoch 99: LearningRateScheduler setting learning rate to 2.0044136481878526e-05.
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - dir_acc: 0.9531 - loss: 0.0208
# Epoch 99: dir_acc did not improve from 0.96780
#
# Epoch 99: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - dir_acc: 0.9539 - loss: 0.0209 - val_dir_acc: 0.6192 - val_loss: 0.0775 - learning_rate: 2.0044e-05
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.25122989794201e-05.
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - dir_acc: 0.9635 - loss: 0.0220
# Epoch 100: dir_acc did not improve from 0.96780
#
# Epoch 100: val_dir_acc did not improve from 0.65768
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - dir_acc: 0.9633 - loss: 0.0219 - val_dir_acc: 0.6192 - val_loss: 0.0778 - learning_rate: 1.2512e-05

# %%
# Load Weights
model.load_weights("transformer_val_model.keras")

# Make predictions
accuracy = model.evaluate(X_test, y_test)[1]
print(f"MODEL ACCURACY: {accuracy}")

# Calculate additional metrics as needed
from sklearn.metrics import r2_score

predictions = model.predict(X_test)
r2 = r2_score(y_test, predictions)
print(f"R-squared: {r2}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dir_acc: 0.6408 - loss: 0.1576
# MODEL ACCURACY: 0.6270161271095276
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step
# R-squared: 0.2724866070113232

# %%
# -------------------------
# Evaluation
# -------------------------

# Inverse scale predictions and actuals
y_pred_inv = scaler_y.inverse_transform(predictions)
y_test_inv = scaler_y.inverse_transform(y_test)

r2 = r2_score(y_test_inv, y_pred_inv)
print(f"R² score: {r2:.4f}")

plt.figure(figsize=(10, 5))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('Actual vs. Predicted Closing Prices')
plt.xlabel('Sample Index')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# R² score: 0.2725

# %%
import pandas as pd
import numpy as np

# Load the test file
try:
    aapl_x_test = pd.read_csv("../../data/input_data_splits/aapl_X_test.csv")
except FileNotFoundError:
    print("The file 'aapl_X_test.csv' was not found. Ensure the file is in the correct directory.")
    raise

# Ensure that the number of samples in y_pred_inv matches the length of the test file
# Take the last n samples from the test file where n is the length of y_pred_inv
n = len(y_pred_inv)
if n > len(aapl_x_test):
    raise ValueError("The number of predictions exceeds the rows in the test file.")

aapl_x_test_shrunk = aapl_x_test.iloc[-n:].copy()

# Ensure the date column exists
if 'Date' not in aapl_x_test_shrunk.columns:
    raise KeyError("The 'Date' column is not found in the test file. Ensure the file has a 'date' column.")

# Create a new DataFrame where the index is the 'date' column from the shrunk test file
# and the values are from y_pred_inv
output_df = pd.DataFrame({
    'Date': aapl_x_test_shrunk['Date'].values,
    'predicted_closing_price': y_pred_inv.flatten()  # Flatten if y_pred_inv is 2D
})

# Save the DataFrame to a CSV file
output_csv_path = "../../data/final_output_data/aaplTransformerpred.csv"
output_df.to_csv(output_csv_path, index=False)

print(f"The file was successfully saved to {output_csv_path}")
# Out:
# The file was successfully saved to ../../data/final_output_data/aaplTransofmerpred.csv
